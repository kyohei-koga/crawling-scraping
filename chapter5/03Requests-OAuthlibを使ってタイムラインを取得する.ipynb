# %%
import pandas as pd
from requests_oauthlib import OAuth1Session

path = '/home/kyohei/crawling-scraping/chapter5/api.csv'
api = pd.read_csv(path, header=None, names=['name', 'value'])

# 認証情報を取得する。
CONSUMER_KEY = api.loc[0, 'value']
CONSUMER_SECRET = api.loc[1, 'value']
ACCESS_TOKEN = api.loc[2, 'value']
ACCESS_TOKEN_SECRET = api.loc[3, 'value']
# 認証情報を使ってOAuth1Sessionオブジェクトを得る。
twitter = OAuth1Session(CONSUMER_KEY,
                        client_secret=CONSUMER_SECRET,
                        resource_owner_key=ACCESS_TOKEN,
                        resource_owner_secret=ACCESS_TOKEN_SECRET)

# ユーザーのタイムラインを取得する。
response = twitter.get('https://api.twitter.com/1.1/statuses/home_timeline.json')

# APIのレスポンスはJSON形式の文字列なので、response.json()でパースしてlistを取得できる。
# statusはツイート（Twitter APIではStatusと呼ばれる）を表すdict。
for status in response.json():
    print('@' + status['user']['screen_name'], status['text'])  # ユーザー名とツイートを表示する。
# Out:
# @smith796000 RT @gorogorounicorn: @smith796000 昨日、大阪の朝日放送のキャストという番組で、青木某がロシアの雑なプロパガンダをそのまま得意気にコメントしてました。
# コーヒー吹き出しそうになりましたよw
# 「こいつ、おもっくそ釣られてるやん」
# 局を挙げてそういう…
# @smith796000 RT @David_R_Stanton: 安倍総理のアメリカ訪問を「失敗」と断じた新聞があったそうですがそいつはバカです。今回の日米首脳会談は目も眩む程の大成功です。その成果がこの共同会見に集約されております。私は「アメリカ大統領が日本の総理にここまで言ってくれるのか」と感動し…
# @Reuters_co_jp 河野外相、北朝鮮で「一歩前進」  https://t.co/wzshHzddBD
# @smith796000 RT @chanelcrara: Retweeted Aisora (@Aisora2a):
#
# @OhIJoinRink @smith796000 北朝鮮とシリアの繋がり。上念さんのファンならチャンネルくらら見ましょう。
# 楽しく学ぼう！シリア現代史番外編「シリアと北朝鮮」内藤陽…
# @smith796000 RT @mchumbayamasai: @smith796000 海外在住です。安倍首相とトランプ大統領との共同会見　breaking newsでLive 。安倍首相の評価安倍高かったです。ここで見ることの出来るNHKプライムニュースでの扱いが信じられない！
# @TheIoT As of May, 3 ORBCOMM Inc. (ORBC) EPS Estimated At $-0.11 https://t.co/ssEzzSmJeL #IoT
# @TheIoT 196800 Shares in USA Technologies (NASDAQ:USAT) Acquired by Cornerstone Capit... https://t.co/PjbDR23Y4y #IoT
# @stattan 夜の勉強は効率が悪いわ。よく寝て，昼間に集中しましょう。おやすみなさい。
# @eigotan_S 【解答】in advance 「前もって、あらかじめ」だよね。advancedの「上級の、前に進んだ」っていうイメージは大切で、そこから「前」の意味が強いの。advance money「前貸しする」の表現自体は、余裕のある人だけで大丈夫だよ。★★★☆☆
# @Reuters_co_jp 大谷２安打、エンゼルス４連敗  https://t.co/cQNmg3IGhL
# @nikkei ハリル氏が再来日、涙も　「捨てられた」と心情 https://t.co/Ez2glSCA58
# @Reuters_co_jp 傷は肺到達か、千葉の会社員刺傷  https://t.co/LcKjYk005B
# @kirik 4月24日、メディアミートアップってのに登壇するんですが - やまもといちろう 公式ブログ https://t.co/AtQDjN0p6D
# @eigotan_S 【問題】advance money「前貸しする」という表現がある。ここでのadvanceの意味を考え、同様のニュアンスで使うイディオムを挙げよ。【答は次】
# @Reuters_co_jp 野党「麻生氏辞任で審議復帰」  https://t.co/pYeRZiM4ga
# @TJO_datasci 例えば2018年の日本にすら「生まれてこのかた研究一筋の研究者として生きてきて、新卒でも中途でも一度も企業就活したことがないのが誇り」とか公言する大学教員とか実在するので
# @WSJJapan 脳機能向上させる神経インプラント、その代償は https://t.co/3BT2PbHmWT
# @TJO_datasci 世俗から隔絶して孤高を保つことこそが至高という価値観の世界、世の中には幾つもありそう
# @TJO_datasci RT @hee_verm: 哲学科のオリエンで教員が「この学科に来たら就職できません」みたいな発話がいまだに出るの信じがたいけど、この手の紋切り型の口上には「就職できない（≒市場価値をもたない）ことにこそ真の価値がある」みたいなルサンチマンが透けて見えるし、その浅薄さと狭量さの…
# @eigotan_S 【解答】訳語だけで言ってしまえば、even ifは「たとえ～であっても」っていう仮定的な事柄、even thoughは「～であるのに」っていう事実的な事柄と一緒に使うわ。辞書や問題集で例文に触れてみて！★★★★☆

# %%
response.json()
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 15:03:29 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 171732438,
#      'id_str': '171732438',
#      'indices': [3, 18],
#      'name': 'Sidai マサイの恋人',
#      'screen_name': 'mchumbayamasai'},
#     {'id': 57870730,
#      'id_str': '57870730',
#      'indices': [20, 32],
#      'name': '上念\u3000司',
#      'screen_name': 'smith796000'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 987708405262553094,
#   'id_str': '987708405262553094',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 2,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Apr 21 14:38:09 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 57870730,
#       'id_str': '57870730',
#       'indices': [0, 12],
#       'name': '上念\u3000司',
#       'screen_name': 'smith796000'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 987702029966491649,
#    'id_str': '987702029966491649',
#    'in_reply_to_screen_name': 'smith796000',
#    'in_reply_to_status_id': 987616558053842945,
#    'in_reply_to_status_id_str': '987616558053842945',
#    'in_reply_to_user_id': 57870730,
#    'in_reply_to_user_id_str': '57870730',
#    'is_quote_status': False,
#    'lang': 'ja',
#    'place': None,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': '@smith796000 海外在住です。安倍首相とトランプ大統領との共同会見\u3000breaking newsでLive 。安倍首相の評価安倍高かったです。ここで見ることの出来るNHKプライムニュースでの扱いが信じられない！',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jul 28 01:31:29 +0000 2010',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1688,
#     'follow_request_sent': False,
#     'followers_count': 14,
#     'following': False,
#     'friends_count': 44,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 171732438,
#     'id_str': '171732438',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'ja',
#     'listed_count': 0,
#     'location': '',
#     'name': 'Sidai マサイの恋人',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/171732438/1499757681',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/884674360648228868/gu6begFT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/884674360648228868/gu6begFT_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'mchumbayamasai',
#     'statuses_count': 1188,
#     'time_zone': 'Tokyo',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 32400,
#     'verified': False}},
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': 'RT @mchumbayamasai: @smith796000 海外在住です。安倍首相とトランプ大統領との共同会見\u3000breaking newsでLive 。安倍首相の評価安倍高かったです。ここで見ることの出来るNHKプライムニュースでの扱いが信じられない！',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jul 18 06:12:05 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '経済評論家\u3000著作：『経済で読み解く織田信長 （KKベストセラーズ）』  『財務省と大新聞が隠す本当は世界一の日本経済（講談社）』『日本は破産しない（宝島社）』\u3000出演：おはよう寺ちゃん（文化放送）、ニュース女子（ＤＨＣテレビ）、報道特注（文化人ＴＶ）など',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'facebook.com/jonen.tsukasa',
#        'expanded_url': 'https://www.facebook.com/jonen.tsukasa',
#        'indices': [0, 23],
#        'url': 'https://t.co/Xi695gWdFr'}]}},
#    'favourites_count': 34,
#    'follow_request_sent': False,
#    'followers_count': 133795,
#    'following': True,
#    'friends_count': 339,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 57870730,
#    'id_str': '57870730',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 3336,
#    'location': '東京都',
#    'name': '上念\u3000司',
#    'notifications': False,
#    'profile_background_color': '709397',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/33893087/PA03-Squared.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/33893087/PA03-Squared.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/57870730/1511062706',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1516936478/twitter_normal.JPG',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1516936478/twitter_normal.JPG',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '86A4A6',
#    'profile_sidebar_fill_color': 'D4D396',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'smith796000',
#    'statuses_count': 58755,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/Xi695gWdFr',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 15:00:20 +0000 2018',
#   'entities': {'hashtags': [{'indices': [81, 85], 'text': 'IoT'}],
#    'symbols': [],
#    'urls': [{'display_url': 'alltheinternetofthings.com/entries/324373',
#      'expanded_url': 'https://alltheinternetofthings.com/entries/324373',
#      'indices': [57, 80],
#      'url': 'https://t.co/ssEzzSmJeL'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 987707613088505856,
#   'id_str': '987707613088505856',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://alltheinternetofthings.com/" rel="nofollow">TheIoT</a>',
#   'text': 'As of May, 3 ORBCOMM Inc. (ORBC) EPS Estimated At $-0.11 https://t.co/ssEzzSmJeL #IoT',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri May 07 20:20:16 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'The best source of #IoT news, by @JamesChevalier - weekly email: https://t.co/kzGwSbfexc - search: https://t.co/6TDaK7shoP',
#    'entities': {'description': {'urls': [{'display_url': 'weekly.alltheinternetofthings.com',
#        'expanded_url': 'http://weekly.alltheinternetofthings.com',
#        'indices': [65, 88],
#        'url': 'https://t.co/kzGwSbfexc'},
#       {'display_url': 'alltheinternetofthings.com/explore',
#        'expanded_url': 'https://alltheinternetofthings.com/explore',
#        'indices': [99, 122],
#        'url': 'https://t.co/6TDaK7shoP'}]},
#     'url': {'urls': [{'display_url': 'alltheinternetofthings.com',
#        'expanded_url': 'https://alltheinternetofthings.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/anmMu4XZfO'}]}},
#    'favourites_count': 85053,
#    'follow_request_sent': False,
#    'followers_count': 91956,
#    'following': True,
#    'friends_count': 626,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 141333525,
#    'id_str': '141333525',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3543,
#    'location': '',
#    'name': 'Internet of Things',
#    'notifications': False,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/141333525/1399941868',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/692535181283061761/1hSF3Nhc_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692535181283061761/1hSF3Nhc_normal.png',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'A8C7F7',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TheIoT',
#    'statuses_count': 154912,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/anmMu4XZfO',
#    'utc_offset': -14400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 15:00:14 +0000 2018',
#   'entities': {'hashtags': [{'indices': [105, 109], 'text': 'IoT'}],
#    'symbols': [],
#    'urls': [{'display_url': 'alltheinternetofthings.com/entries/324372',
#      'expanded_url': 'https://alltheinternetofthings.com/entries/324372',
#      'indices': [81, 104],
#      'url': 'https://t.co/PjbDR23Y4y'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 987707586861588481,
#   'id_str': '987707586861588481',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://alltheinternetofthings.com/" rel="nofollow">TheIoT</a>',
#   'text': '196800 Shares in USA Technologies (NASDAQ:USAT) Acquired by Cornerstone Capit... https://t.co/PjbDR23Y4y #IoT',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri May 07 20:20:16 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'The best source of #IoT news, by @JamesChevalier - weekly email: https://t.co/kzGwSbfexc - search: https://t.co/6TDaK7shoP',
#    'entities': {'description': {'urls': [{'display_url': 'weekly.alltheinternetofthings.com',
#        'expanded_url': 'http://weekly.alltheinternetofthings.com',
#        'indices': [65, 88],
#        'url': 'https://t.co/kzGwSbfexc'},
#       {'display_url': 'alltheinternetofthings.com/explore',
#        'expanded_url': 'https://alltheinternetofthings.com/explore',
#        'indices': [99, 122],
#        'url': 'https://t.co/6TDaK7shoP'}]},
#     'url': {'urls': [{'display_url': 'alltheinternetofthings.com',
#        'expanded_url': 'https://alltheinternetofthings.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/anmMu4XZfO'}]}},
#    'favourites_count': 85053,
#    'follow_request_sent': False,
#    'followers_count': 91956,
#    'following': True,
#    'friends_count': 626,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 141333525,
#    'id_str': '141333525',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3543,
#    'location': '',
#    'name': 'Internet of Things',
#    'notifications': False,
#    'profile_background_color': '022330',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/141333525/1399941868',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/692535181283061761/1hSF3Nhc_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692535181283061761/1hSF3Nhc_normal.png',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'A8C7F7',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TheIoT',
#    'statuses_count': 154912,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/anmMu4XZfO',
#    'utc_offset': -14400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:55:52 +0000 2018',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 987706491745591301,
#   'id_str': '987706491745591301',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#   'text': '夜の勉強は効率が悪いわ。よく寝て，昼間に集中しましょう。おやすみなさい。',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Apr 30 12:07:27 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '統計に興味が有る方，必修・卒論で必要な方，一度勉強したけど結局わからなかった方など幅広く対応できたらと思います。 統計手法と原理，ソフトウェアの使い方・結果の読み方，書籍紹介，統計ネタをつぶやきます。 イラストはきらさんに描いて頂きました！方針などはプロフィールを参照ください。',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'twpf.jp/stattan',
#        'expanded_url': 'http://twpf.jp/stattan',
#        'indices': [0, 23],
#        'url': 'https://t.co/yvwkDaD9vF'}]}},
#    'favourites_count': 11385,
#    'follow_request_sent': False,
#    'followers_count': 6671,
#    'following': True,
#    'friends_count': 368,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1391913758,
#    'id_str': '1391913758',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 326,
#    'location': 'とあるRのなか',
#    'name': '統計たん@本質的に不良設定問題',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1391913758/1367425278',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000025701134/d74ec62d2975fbf9a2920e7000a806b1_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000025701134/d74ec62d2975fbf9a2920e7000a806b1_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'stattan',
#    'statuses_count': 32794,
#    'time_zone': 'Irkutsk',
#    'translator_type': 'none',
#    'url': 'https://t.co/yvwkDaD9vF',
#    'utc_offset': 28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:52:45 +0000 2018',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 987705703648321536,
#   'id_str': '987705703648321536',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#   'text': '【解答】in advance 「前もって、あらかじめ」だよね。advancedの「上級の、前に進んだ」っていうイメージは大切で、そこから「前」の意味が強いの。advance money「前貸しする」の表現自体は、余裕のある人だけで大丈夫だよ。★★★☆☆',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Nov 26 16:15:45 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '英語たん( @eigotan)のもう一つのStyle。GMARCH上位～早慶上智外大以上を目指す方にオススメ。Studentsのための、SuperでSmartでSpecialで、そしてちょっぴりSadisticな、Sakura咲かせるための英語たん。さぁ、Shall we dance？ (2013/02/03-)',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'sites.google.com/site/eigotange…',
#        'expanded_url': 'https://sites.google.com/site/eigotangel/',
#        'indices': [0, 23],
#        'url': 'https://t.co/h1abILQBBA'}]}},
#    'favourites_count': 110,
#    'follow_request_sent': False,
#    'followers_count': 26445,
#    'following': True,
#    'friends_count': 21,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 421952694,
#    'id_str': '421952694',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 1085,
#    'location': '49ページ16行目。',
#    'name': '英語たん【S】@問題追加！',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/778090967/27c096eade9db38b729b504cabb01b5c.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/778090967/27c096eade9db38b729b504cabb01b5c.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/421952694/1471791879',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/781819162767220740/WGpFWxov_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/781819162767220740/WGpFWxov_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'eigotan_S',
#    'statuses_count': 89776,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/h1abILQBBA',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:50:20 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'reut.rs/2F62RQr',
#      'expanded_url': 'https://reut.rs/2F62RQr',
#      'indices': [16, 39],
#      'url': 'https://t.co/cQNmg3IGhL'}],
#    'user_mentions': []},
#   'favorite_count': 15,
#   'favorited': False,
#   'geo': None,
#   'id': 987705098775212033,
#   'id_str': '987705098775212033',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 8,
#   'retweeted': False,
#   'source': '<a href="http://trueanthem.com/" rel="nofollow">trueAnthem</a>',
#   'text': '大谷２安打、エンゼルス４連敗  https://t.co/cQNmg3IGhL',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 04 03:36:40 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'ロイター日本語サイト編集部がトップニュースやブログ、コラム、そしておすすめのスライドショーやビデオをお届けする公式ツイッターアカウントです。ロイターのフェイスブックページはこちらhttps://t.co/tRAfpsw4yn',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/1TeeabU',
#        'expanded_url': 'http://bit.ly/1TeeabU',
#        'indices': [89, 112],
#        'url': 'https://t.co/tRAfpsw4yn'}]},
#     'url': {'urls': [{'display_url': 'jp.reuters.com',
#        'expanded_url': 'https://jp.reuters.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/AJXNk8ATe2'}]}},
#    'favourites_count': 4,
#    'follow_request_sent': False,
#    'followers_count': 649706,
#    'following': True,
#    'friends_count': 40,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 119603478,
#    'id_str': '119603478',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 18085,
#    'location': 'Tokyo, Japan',
#    'name': 'ロイター.co.jp',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/119603478/1523962768',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_link_color': '4DA2DE',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'D9D9D5',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Reuters_co_jp',
#    'statuses_count': 146153,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/AJXNk8ATe2',
#    'utc_offset': 32400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:49:00 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'nikkei.com/article/DGXMZO…',
#      'expanded_url': 'https://www.nikkei.com/article/DGXMZO2969289021042018I00000/?n_cid=SNSTW001',
#      'indices': [23, 46],
#      'url': 'https://t.co/Ez2glSCA58'}],
#    'user_mentions': []},
#   'favorite_count': 35,
#   'favorited': False,
#   'geo': None,
#   'id': 987704761511104512,
#   'id_str': '987704761511104512',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 30,
#   'retweeted': False,
#   'source': '<a href="http://www.nikkei.com/" rel="nofollow">日本経済新聞 電子版</a>',
#   'text': 'ハリル氏が再来日、涙も\u3000「捨てられた」と心情 https://t.co/Ez2glSCA58',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jul 22 12:58:30 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '日本経済新聞 電子版（日経電子版）の公式アカウントです。電子版トップページで報じたニュースや解説、コラムのほか、お薦めのコンテンツを発信します。',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'nikkei.com',
#        'expanded_url': 'http://www.nikkei.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/omGYnfa1KL'}]}},
#    'favourites_count': 14,
#    'follow_request_sent': False,
#    'followers_count': 2968657,
#    'following': True,
#    'friends_count': 34,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 169480493,
#    'id_str': '169480493',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 39169,
#    'location': '',
#    'name': '日本経済新聞 電子版',
#    'notifications': False,
#    'profile_background_color': '0F3675',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/132863093/bg_03.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/132863093/bg_03.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/169480493/1519009422',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/926053940449263616/1I1Q_Plx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/926053940449263616/1I1Q_Plx_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'DFDFDF',
#    'profile_sidebar_fill_color': 'F3F3F3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'nikkei',
#    'statuses_count': 204031,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'http://t.co/omGYnfa1KL',
#    'utc_offset': 32400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:30:30 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'reut.rs/2Jcx82r',
#      'expanded_url': 'https://reut.rs/2Jcx82r',
#      'indices': [17, 40],
#      'url': 'https://t.co/LcKjYk005B'}],
#    'user_mentions': []},
#   'favorite_count': 8,
#   'favorited': False,
#   'geo': None,
#   'id': 987700106873929731,
#   'id_str': '987700106873929731',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 12,
#   'retweeted': False,
#   'source': '<a href="http://trueanthem.com/" rel="nofollow">trueAnthem</a>',
#   'text': '傷は肺到達か、千葉の会社員刺傷  https://t.co/LcKjYk005B',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 04 03:36:40 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'ロイター日本語サイト編集部がトップニュースやブログ、コラム、そしておすすめのスライドショーやビデオをお届けする公式ツイッターアカウントです。ロイターのフェイスブックページはこちらhttps://t.co/tRAfpsw4yn',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/1TeeabU',
#        'expanded_url': 'http://bit.ly/1TeeabU',
#        'indices': [89, 112],
#        'url': 'https://t.co/tRAfpsw4yn'}]},
#     'url': {'urls': [{'display_url': 'jp.reuters.com',
#        'expanded_url': 'https://jp.reuters.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/AJXNk8ATe2'}]}},
#    'favourites_count': 4,
#    'follow_request_sent': False,
#    'followers_count': 649706,
#    'following': True,
#    'friends_count': 40,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 119603478,
#    'id_str': '119603478',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 18085,
#    'location': 'Tokyo, Japan',
#    'name': 'ロイター.co.jp',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/119603478/1523962768',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_link_color': '4DA2DE',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'D9D9D5',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Reuters_co_jp',
#    'statuses_count': 146153,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/AJXNk8ATe2',
#    'utc_offset': 32400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:24:45 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'lineblog.me/yamamotoichiro…',
#      'expanded_url': 'https://lineblog.me/yamamotoichiro/archives/13182051.html',
#      'indices': [46, 69],
#      'url': 'https://t.co/AtQDjN0p6D'}],
#    'user_mentions': []},
#   'favorite_count': 10,
#   'favorited': False,
#   'geo': None,
#   'id': 987698660350746625,
#   'id_str': '987698660350746625',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '4月24日、メディアミートアップってのに登壇するんですが - やまもといちろう 公式ブログ https://t.co/AtQDjN0p6D',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 19 05:41:05 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '投資家、作家。なるだけ頂戴したメンション返しますが、流れが速いと読んでないので返信されなくても泣かないでください。また、スパム増加につき、フォロワー数の少ないアカウントは自動ブロックされてしまいます、すみません。プロフィールはブログ参照、ツイートは個人の意見です。ゲーム&個人垢→@kirik_game',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'lineblog.me/yamamotoichiro/',
#        'expanded_url': 'http://lineblog.me/yamamotoichiro/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Rr3g2usbe8'}]}},
#    'favourites_count': 97,
#    'follow_request_sent': False,
#    'followers_count': 124882,
#    'following': True,
#    'friends_count': 192,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 5191991,
#    'id_str': '5191991',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 5181,
#    'location': '東京都 千代田区',
#    'name': '山本一郎(やまもといちろう@告知用)',
#    'notifications': False,
#    'profile_background_color': '006000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5191991/1496842562',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/671948353190555648/W8RujqPt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/671948353190555648/W8RujqPt_normal.jpg',
#    'profile_link_color': '008800',
#    'profile_sidebar_border_color': '87BC44',
#    'profile_sidebar_fill_color': '008800',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'kirik',
#    'statuses_count': 46542,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/Rr3g2usbe8',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:22:44 +0000 2018',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 987698150100975616,
#   'id_str': '987698150100975616',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twittbot.net/" rel="nofollow">twittbot.net</a>',
#   'text': '【問題】advance money「前貸しする」という表現がある。ここでのadvanceの意味を考え、同様のニュアンスで使うイディオムを挙げよ。【答は次】',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Nov 26 16:15:45 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '英語たん( @eigotan)のもう一つのStyle。GMARCH上位～早慶上智外大以上を目指す方にオススメ。Studentsのための、SuperでSmartでSpecialで、そしてちょっぴりSadisticな、Sakura咲かせるための英語たん。さぁ、Shall we dance？ (2013/02/03-)',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'sites.google.com/site/eigotange…',
#        'expanded_url': 'https://sites.google.com/site/eigotangel/',
#        'indices': [0, 23],
#        'url': 'https://t.co/h1abILQBBA'}]}},
#    'favourites_count': 110,
#    'follow_request_sent': False,
#    'followers_count': 26445,
#    'following': True,
#    'friends_count': 21,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 421952694,
#    'id_str': '421952694',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 1085,
#    'location': '49ページ16行目。',
#    'name': '英語たん【S】@問題追加！',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/778090967/27c096eade9db38b729b504cabb01b5c.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/778090967/27c096eade9db38b729b504cabb01b5c.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/421952694/1471791879',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/781819162767220740/WGpFWxov_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/781819162767220740/WGpFWxov_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'eigotan_S',
#    'statuses_count': 89776,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/h1abILQBBA',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:05:25 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'reut.rs/2F4RW9T',
#      'expanded_url': 'https://reut.rs/2F4RW9T',
#      'indices': [16, 39],
#      'url': 'https://t.co/pYeRZiM4ga'}],
#    'user_mentions': []},
#   'favorite_count': 23,
#   'favorited': False,
#   'geo': None,
#   'id': 987693795088191488,
#   'id_str': '987693795088191488',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 35,
#   'retweeted': False,
#   'source': '<a href="http://trueanthem.com/" rel="nofollow">trueAnthem</a>',
#   'text': '野党「麻生氏辞任で審議復帰」  https://t.co/pYeRZiM4ga',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 04 03:36:40 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'ロイター日本語サイト編集部がトップニュースやブログ、コラム、そしておすすめのスライドショーやビデオをお届けする公式ツイッターアカウントです。ロイターのフェイスブックページはこちらhttps://t.co/tRAfpsw4yn',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/1TeeabU',
#        'expanded_url': 'http://bit.ly/1TeeabU',
#        'indices': [89, 112],
#        'url': 'https://t.co/tRAfpsw4yn'}]},
#     'url': {'urls': [{'display_url': 'jp.reuters.com',
#        'expanded_url': 'https://jp.reuters.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/AJXNk8ATe2'}]}},
#    'favourites_count': 4,
#    'follow_request_sent': False,
#    'followers_count': 649706,
#    'following': True,
#    'friends_count': 40,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 119603478,
#    'id_str': '119603478',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 18085,
#    'location': 'Tokyo, Japan',
#    'name': 'ロイター.co.jp',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/119603478/1523962768',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_link_color': '4DA2DE',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'D9D9D5',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Reuters_co_jp',
#    'statuses_count': 146153,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/AJXNk8ATe2',
#    'utc_offset': 32400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:02:55 +0000 2018',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 12,
#   'favorited': False,
#   'geo': None,
#   'id': 987693162335367168,
#   'id_str': '987693162335367168',
#   'in_reply_to_screen_name': 'TJO_datasci',
#   'in_reply_to_status_id': 987691527051755523,
#   'in_reply_to_status_id_str': '987691527051755523',
#   'in_reply_to_user_id': 1320611023,
#   'in_reply_to_user_id_str': '1320611023',
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 4,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '例えば2018年の日本にすら「生まれてこのかた研究一筋の研究者として生きてきて、新卒でも中途でも一度も企業就活したことがないのが誇り」とか公言する大学教員とか実在するので',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Apr 01 15:45:09 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Takashi J Ozaki PhD, Data Scientist @Google https://t.co/MGpEyW8G3F https://t.co/LXDKFB07Tv Tweets are my own, not views of my employer, wiped every 12h',
#    'entities': {'description': {'urls': [{'display_url': 'tjo.hatenablog.com',
#        'expanded_url': 'https://tjo.hatenablog.com',
#        'indices': [44, 67],
#        'url': 'https://t.co/MGpEyW8G3F'},
#       {'display_url': 'tjo-en.hatenablog.com',
#        'expanded_url': 'http://tjo-en.hatenablog.com',
#        'indices': [68, 91],
#        'url': 'https://t.co/LXDKFB07Tv'}]},
#     'url': {'urls': [{'display_url': 'linkedin.com/in/tjozaki',
#        'expanded_url': 'https://www.linkedin.com/in/tjozaki',
#        'indices': [0, 23],
#        'url': 'https://t.co/MbV653tMzS'}]}},
#    'favourites_count': 14890,
#    'follow_request_sent': False,
#    'followers_count': 17859,
#    'following': True,
#    'friends_count': 398,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1320611023,
#    'id_str': '1320611023',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 759,
#    'location': 'Roppongi, Tokyo',
#    'name': 'TJO',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1320611023/1483288037',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/875866978371502080/FNU_qiqO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875866978371502080/FNU_qiqO_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TJO_datasci',
#    'statuses_count': 45696,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/MbV653tMzS',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 14:00:25 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'on.wsj.com/2qNrNqN',
#      'expanded_url': 'https://on.wsj.com/2qNrNqN',
#      'indices': [23, 46],
#      'url': 'https://t.co/3BT2PbHmWT'}],
#    'user_mentions': []},
#   'favorite_count': 23,
#   'favorited': False,
#   'geo': None,
#   'id': 987692534036971521,
#   'id_str': '987692534036971521',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 11,
#   'retweeted': False,
#   'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#   'text': '脳機能向上させる神経インプラント、その代償は https://t.co/3BT2PbHmWT',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jun 22 06:43:35 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '【WSJ日本版】 https://t.co/r7VHrtcsDs【LINE】 https://t.co/MzcHymOKv8\n【Facebook】 https://t.co/DVDQJUHPo6',
#    'entities': {'description': {'urls': [{'display_url': 'jp.wsj.com',
#        'expanded_url': 'http://jp.wsj.com/',
#        'indices': [9, 32],
#        'url': 'https://t.co/r7VHrtcsDs'},
#       {'display_url': 'bitly.com/LINEWSJ',
#        'expanded_url': 'http://bitly.com/LINEWSJ',
#        'indices': [39, 62],
#        'url': 'https://t.co/MzcHymOKv8'},
#       {'display_url': 'facebook.com/japanwsj',
#        'expanded_url': 'https://www.facebook.com/japanwsj',
#        'indices': [74, 97],
#        'url': 'https://t.co/DVDQJUHPo6'}]},
#     'url': {'urls': [{'display_url': 'jp.wsj.com',
#        'expanded_url': 'http://jp.wsj.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/jKT4ccm2W7'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': False,
#    'followers_count': 926277,
#    'following': True,
#    'friends_count': 44,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 49559086,
#    'id_str': '49559086',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 22179,
#    'location': '東京',
#    'name': 'ウォール・ストリート・ジャーナル日本版',
#    'notifications': False,
#    'profile_background_color': '3A3838',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000081208527/81f0474fec250de3ed5574163a6a182e.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000081208527/81f0474fec250de3ed5574163a6a182e.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49559086/1416208167',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/533079575547228163/ruFUeUOf_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/533079575547228163/ruFUeUOf_normal.png',
#    'profile_link_color': '0B3E78',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'F4F1E8',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'WSJJapan',
#    'statuses_count': 141550,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'http://t.co/jKT4ccm2W7',
#    'utc_offset': 32400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 13:56:25 +0000 2018',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 9,
#   'favorited': False,
#   'geo': None,
#   'id': 987691527051755523,
#   'id_str': '987691527051755523',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '世俗から隔絶して孤高を保つことこそが至高という価値観の世界、世の中には幾つもありそう',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Apr 01 15:45:09 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Takashi J Ozaki PhD, Data Scientist @Google https://t.co/MGpEyW8G3F https://t.co/LXDKFB07Tv Tweets are my own, not views of my employer, wiped every 12h',
#    'entities': {'description': {'urls': [{'display_url': 'tjo.hatenablog.com',
#        'expanded_url': 'https://tjo.hatenablog.com',
#        'indices': [44, 67],
#        'url': 'https://t.co/MGpEyW8G3F'},
#       {'display_url': 'tjo-en.hatenablog.com',
#        'expanded_url': 'http://tjo-en.hatenablog.com',
#        'indices': [68, 91],
#        'url': 'https://t.co/LXDKFB07Tv'}]},
#     'url': {'urls': [{'display_url': 'linkedin.com/in/tjozaki',
#        'expanded_url': 'https://www.linkedin.com/in/tjozaki',
#        'indices': [0, 23],
#        'url': 'https://t.co/MbV653tMzS'}]}},
#    'favourites_count': 14890,
#    'follow_request_sent': False,
#    'followers_count': 17859,
#    'following': True,
#    'friends_count': 398,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1320611023,
#    'id_str': '1320611023',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 759,
#    'location': 'Roppongi, Tokyo',
#    'name': 'TJO',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1320611023/1483288037',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/875866978371502080/FNU_qiqO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875866978371502080/FNU_qiqO_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TJO_datasci',
#    'statuses_count': 45696,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/MbV653tMzS',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 13:55:20 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 281029588,
#      'id_str': '281029588',
#      'indices': [3, 12],
#      'name': 'heechulju',
#      'screen_name': 'hee_verm'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 987691256225579009,
#   'id_str': '987691256225579009',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 263,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Apr 21 00:56:55 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 696,
#    'favorited': False,
#    'geo': None,
#    'id': 987495361177571328,
#    'id_str': '987495361177571328',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'ja',
#    'place': None,
#    'retweet_count': 263,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '哲学科のオリエンで教員が「この学科に来たら就職できません」みたいな発話がいまだに出るの信じがたいけど、この手の紋切り型の口上には「就職できない（≒市場価値をもたない）ことにこそ真の価値がある」みたいなルサンチマンが透けて見えるし、その浅薄さと狭量さの方に失望すべきだと思う。',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Apr 12 13:51:28 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
# ...
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/Rr3g2usbe8',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 13:50:21 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'reut.rs/2JaKfBu',
#      'expanded_url': 'https://reut.rs/2JaKfBu',
#      'indices': [27, 50],
#      'url': 'https://t.co/QDHl1Z0KMG'}],
#    'user_mentions': []},
#   'favorite_count': 14,
#   'favorited': False,
#   'geo': None,
#   'id': 987689999868088321,
#   'id_str': '987689999868088321',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'retweet_count': 9,
#   'retweeted': False,
#   'source': '<a href="http://trueanthem.com/" rel="nofollow">trueAnthem</a>',
#   'text': '日米で通商巡り違いあるのは事実＝Ｇ２０で麻生財務相  https://t.co/QDHl1Z0KMG',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 04 03:36:40 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'ロイター日本語サイト編集部がトップニュースやブログ、コラム、そしておすすめのスライドショーやビデオをお届けする公式ツイッターアカウントです。ロイターのフェイスブックページはこちらhttps://t.co/tRAfpsw4yn',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/1TeeabU',
#        'expanded_url': 'http://bit.ly/1TeeabU',
#        'indices': [89, 112],
#        'url': 'https://t.co/tRAfpsw4yn'}]},
#     'url': {'urls': [{'display_url': 'jp.reuters.com',
#        'expanded_url': 'https://jp.reuters.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/AJXNk8ATe2'}]}},
#    'favourites_count': 4,
#    'follow_request_sent': False,
#    'followers_count': 649706,
#    'following': True,
#    'friends_count': 40,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 119603478,
#    'id_str': '119603478',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 18085,
#    'location': 'Tokyo, Japan',
#    'name': 'ロイター.co.jp',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/119048787/reuters_twitter_bg.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/119603478/1523962768',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/877357487099269120/Mxm5YvoG_normal.jpg',
#    'profile_link_color': '4DA2DE',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'D9D9D5',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Reuters_co_jp',
#    'statuses_count': 146153,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/AJXNk8ATe2',
#    'utc_offset': 32400,
#    'verified': True}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 13:43:58 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1715975720,
#      'id_str': '1715975720',
#      'indices': [3, 17],
#      'name': 'しらたま。＠フリーライター',
#      'screen_name': 'siratama_3gou'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 987688396851048449,
#   'id_str': '987688396851048449',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'ja',
#   'place': None,
#   'quoted_status_id': 987684199149682688,
#   'quoted_status_id_str': '987684199149682688',
#   'retweet_count': 58,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Apr 21 13:41:33 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/987687789360656390',
#       'indices': [117, 140],
#       'url': 'https://t.co/A3FFkroQSe'}],
#     'user_mentions': []},
#    'favorite_count': 63,
#    'favorited': False,
#    'geo': None,
#    'id': 987687789360656390,
#    'id_str': '987687789360656390',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': True,
#    'lang': 'ja',
#    'place': None,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'quoted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Sat Apr 21 13:27:18 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': [{'id': 1715975720,
#        'id_str': '1715975720',
#        'indices': [0, 14],
#        'name': 'しらたま。＠フリーライター',
#        'screen_name': 'siratama_3gou'}]},
#     'favorite_count': 14,
#     'favorited': False,
#     'geo': None,
#     'id': 987684199149682688,
#     'id_str': '987684199149682688',
#     'in_reply_to_screen_name': 'siratama_3gou',
#     'in_reply_to_status_id': 987683900884271104,
#     'in_reply_to_status_id_str': '987683900884271104',
#     'in_reply_to_user_id': 1715975720,
#     'in_reply_to_user_id_str': '1715975720',
#     'is_quote_status': False,
#     'lang': 'ja',
#     'place': None,
#     'retweet_count': 4,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': '@siratama_3gou ほんと、あり得ません…\u3000取材費考えたらほぼ全部持ち出しですので、秒速8万kmでお断りすることに。',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Apr 19 05:41:05 +0000 2007',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '投資家、作家。なるだけ頂戴したメンション返しますが、流れが速いと読んでないので返信されなくても泣かないでください。また、スパム増加につき、フォロワー数の少ないアカウントは自動ブロックされてしまいます、すみません。プロフィールはブログ参照、ツイートは個人の意見です。ゲーム&個人垢→@kirik_game',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'lineblog.me/yamamotoichiro/',
#          'expanded_url': 'http://lineblog.me/yamamotoichiro/',
#          'indices': [0, 23],
#          'url': 'https://t.co/Rr3g2usbe8'}]}},
#      'favourites_count': 97,
#      'follow_request_sent': False,
#      'followers_count': 124882,
#      'following': True,
#      'friends_count': 192,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 5191991,
#      'id_str': '5191991',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'ja',
#      'listed_count': 5181,
#      'location': '東京都 千代田区',
#      'name': '山本一郎(やまもといちろう@告知用)',
#      'notifications': False,
#      'profile_background_color': '006000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5191991/1496842562',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/671948353190555648/W8RujqPt_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/671948353190555648/W8RujqPt_normal.jpg',
#      'profile_link_color': '008800',
#      'profile_sidebar_border_color': '87BC44',
#      'profile_sidebar_fill_color': '008800',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'kirik',
#      'statuses_count': 46542,
#      'time_zone': 'Tokyo',
#      'translator_type': 'none',
#      'url': 'https://t.co/Rr3g2usbe8',
#      'utc_offset': 32400,
#      'verified': False}},
#    'quoted_status_id': 987684199149682688,
#    'quoted_status_id_str': '987684199149682688',
#    'retweet_count': 58,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '知らない人のために解説\n4000文字5000円だと、クラウドソーシングでも取材入るなら赤字。\n全く無名の人が体験談書く旅行系とか、ちょっとライター経験ある人がコタツ記事（ネットサーフィンで調べて書ける範囲）で作れる程度。\n下手な媒… https://t.co/A3FFkroQSe',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Aug 31 15:28:23 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '専業クラウドワーカーでフリーライター。仮想通貨・株などの運用経験有り。顔出し、本名でのお仕事も可。お仕事の依頼はこちら⇒https://t.co/lmxczJd4jv\u30001000文字1250円程度からお仕事を承ります。\u3000アイコン作成⇒ @roku_mei_kan',
#     'entities': {'description': {'urls': [{'display_url': 'crowdworks.jp/public/employe…',
#         'expanded_url': 'https://crowdworks.jp/public/employees/612583',
#         'indices': [60, 83],
#         'url': 'https://t.co/lmxczJd4jv'}]},
#      'url': {'urls': [{'display_url': 'nekonogohann.blog.jp',
#         'expanded_url': 'http://nekonogohann.blog.jp/',
#         'indices': [0, 23],
#         'url': 'https://t.co/ZcXw5bKVHs'}]}},
#     'favourites_count': 47324,
#     'follow_request_sent': False,
#     'followers_count': 892,
#     'following': False,
#     'friends_count': 1427,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1715975720,
#     'id_str': '1715975720',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'ja',
#     'listed_count': 9,
#     'location': '猫の下敷き',
#     'name': 'しらたま。＠フリーライター',
#     'notifications': False,
#     'profile_background_color': 'ACDED6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1715975720/1485527021',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/887646611492413440/vz6gIfDj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/887646611492413440/vz6gIfDj_normal.jpg',
#     'profile_link_color': '038543',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'siratama_3gou',
#     'statuses_count': 52638,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/ZcXw5bKVHs',
#     'utc_offset': -25200,
#     'verified': False}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @siratama_3gou: 知らない人のために解説\n4000文字5000円だと、クラウドソーシングでも取材入るなら赤字。\n全く無名の人が体験談書く旅行系とか、ちょっとライター経験ある人がコタツ記事（ネットサーフィンで調べて書ける範囲）で作れる程度。\n下手な媒体で掲載す…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Apr 19 05:41:05 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '投資家、作家。なるだけ頂戴したメンション返しますが、流れが速いと読んでないので返信されなくても泣かないでください。また、スパム増加につき、フォロワー数の少ないアカウントは自動ブロックされてしまいます、すみません。プロフィールはブログ参照、ツイートは個人の意見です。ゲーム&個人垢→@kirik_game',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'lineblog.me/yamamotoichiro/',
#        'expanded_url': 'http://lineblog.me/yamamotoichiro/',
#        'indices': [0, 23],
#        'url': 'https://t.co/Rr3g2usbe8'}]}},
#    'favourites_count': 97,
#    'follow_request_sent': False,
#    'followers_count': 124882,
#    'following': True,
#    'friends_count': 192,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 5191991,
#    'id_str': '5191991',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 5181,
#    'location': '東京都 千代田区',
#    'name': '山本一郎(やまもといちろう@告知用)',
#    'notifications': False,
#    'profile_background_color': '006000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5191991/1496842562',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/671948353190555648/W8RujqPt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/671948353190555648/W8RujqPt_normal.jpg',
#    'profile_link_color': '008800',
#    'profile_sidebar_border_color': '87BC44',
#    'profile_sidebar_fill_color': '008800',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'kirik',
#    'statuses_count': 46542,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/Rr3g2usbe8',
#    'utc_offset': 32400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Apr 21 13:42:52 +0000 2018',
#   'entities': {'hashtags': [{'indices': [32, 38], 'text': 'あとで消す'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 19,
#   'favorited': False,
#   'geo': None,
#   'id': 987688117648818181,
#   'id_str': '987688117648818181',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'ja',
#   'place': None,
#   'retweet_count': 2,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '某AI×国語力先生よりもフォロワーが多いことに気付いてしまった #あとで消す',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Apr 01 15:45:09 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Takashi J Ozaki PhD, Data Scientist @Google https://t.co/MGpEyW8G3F https://t.co/LXDKFB07Tv Tweets are my own, not views of my employer, wiped every 12h',
#    'entities': {'description': {'urls': [{'display_url': 'tjo.hatenablog.com',
#        'expanded_url': 'https://tjo.hatenablog.com',
#        'indices': [44, 67],
#        'url': 'https://t.co/MGpEyW8G3F'},
#       {'display_url': 'tjo-en.hatenablog.com',
#        'expanded_url': 'http://tjo-en.hatenablog.com',
#        'indices': [68, 91],
#        'url': 'https://t.co/LXDKFB07Tv'}]},
#     'url': {'urls': [{'display_url': 'linkedin.com/in/tjozaki',
#        'expanded_url': 'https://www.linkedin.com/in/tjozaki',
#        'indices': [0, 23],
#        'url': 'https://t.co/MbV653tMzS'}]}},
#    'favourites_count': 14890,
#    'follow_request_sent': False,
#    'followers_count': 17859,
#    'following': True,
#    'friends_count': 398,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 1320611023,
#    'id_str': '1320611023',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'ja',
#    'listed_count': 759,
#    'location': 'Roppongi, Tokyo',
#    'name': 'TJO',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1320611023/1483288037',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/875866978371502080/FNU_qiqO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875866978371502080/FNU_qiqO_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'TJO_datasci',
#    'statuses_count': 45696,
#    'time_zone': 'Tokyo',
#    'translator_type': 'none',
#    'url': 'https://t.co/MbV653tMzS',
#    'utc_offset': 32400,
#    'verified': False}}]

# %%
api
# Out:
#                   name                                              value
# 0         CONSUMER_KEY                          2fX4lduV3q6HyNJSrzWhvIivm
# 1      CONSUMER_SECRET  lDuTYXPorvkRQ2FlFAbJNBYddT2Jx9eN7vAqbtvLHFOxq6...
# 2         ACCESS_TOKEN  218624055-cmVqs5wjeAhKRhxbVktUDfdxcN93tPesKMuW...
# 3  ACCESS_TOKEN_SECRET      U7VJJ234nWX8HOFazeZeL3Cu6CLCU0o2j2u5pS1HfYggZ

# %%
with open('api.csv') as f:
    reader = csv.reader(f)

# %%
reader
