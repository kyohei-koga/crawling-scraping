# %%
import lxml.html

# %%
#HTMLファイルを読み込み、getroot()メソッドでHtmlElementオブジェクトを得る。
tree = lxml.html.parse('/home/kyohei/index.html')
html = tree.getroot()

# %%
#cssselect()メソッドでa要素のリストを取得して、個々のa要素に対して処理を行う
for a in html.cssselect('a'):
    # href属性とリンクのテキストを取得して表示する
    print(a.get('href'),a.text)
# Out:
# http://gihyo.jp/ None
# http://gihyo.jp/site/inquiry お問い合わせ
# http://gihyo.jp/site/profile 会社案内
# http://gihyo.jp/dev デベロッパ
# http://gihyo.jp/admin アドミニストレータ
# http://gihyo.jp/design WEB＋デザイン
# http://gihyo.jp/lifestyle ライフスタイル
# http://gihyo.jp/book 書籍案内
# https://gihyo.jp/dp 電子書籍
# http://gihyo.jp/lifestyle/serial/01/engineer-x-manage None
# http://gihyo.jp/lifestyle/serial/01/engineer-x-manage エンジニアと経営のクロスオーバー
# http://gihyo.jp/dev/serial/01/voiceui None
# http://gihyo.jp/dev/serial/01/voiceui 優しいUI～ボイスユーザインターフェースで変わるコト
# http://gihyo.jp/admin/serial/01/ad-linux2017 None
# http://gihyo.jp/admin/serial/01/ad-linux2017 Active DirectoryとLinuxの認証を統合しよう【2017年版】
# http://gihyo.jp/admin None
# /admin/clip/01/linux_dt Linux Daily Topics
# /admin/clip/01/linux_dt/201804/06 2018年4月6日　Canonicalの製品担当VPが退職，Google Cloudへ
# http://gihyo.jp/admin/clip/01/linux_dt None
# http://gihyo.jp/news None
# /news/report レポート
# /news/report/2018/04/0501 大規模データを扱うための実践的知識を大公開「CyberAgent Data Engineering & Data Analysis Workshop #4 ～春の機械学習祭り～」レポート
# http://gihyo.jp/news/report/2018/04/0501 None
# http://gihyo.jp/admin None
# /admin/clip/01/ubuntu-topics Ubuntu Weekly Topics
# /admin/clip/01/ubuntu-topics/201804/06 2018年4月6日号　bionicのFinal Beta, Spectre/Meltdown対策さらにさらにその後・4月上旬版
# http://gihyo.jp/admin/clip/01/ubuntu-topics None
# http://gihyo.jp/news None
# /news/info インフォメーション
# /news/info/2018/04/0601 MTDDC Meetup HOKKAIDO 2018，6月9日に北海道・札幌で開催
# http://gihyo.jp/book None
# /book/pickup 新刊ピックアップ
# /book/pickup/2018/0021 現場で求められる技術とは？
# http://gihyo.jp/book None
# /book/pickup 新刊ピックアップ
# /book/pickup/2018/0020 今更聞けない？ クラウドのポイントを押さえよう
# http://gihyo.jp/admin None
# /admin/clip/01/linux_dt Linux Daily Topics
# /admin/clip/01/linux_dt/201804/05 2018年4月5日　モジュラー化に再挑戦した「Fedora 28」ベータ版が登場，正式リリースは5月8日予定
# http://gihyo.jp/admin/clip/01/linux_dt None
# http://gihyo.jp/lifestyle None
# /lifestyle/serial/01/engineer-x-manage エンジニアと経営のクロスオーバー
# /lifestyle/serial/01/engineer-x-manage/0011 第11回　営業をやるとエンジニアライフに絶対にプラスになる
# http://gihyo.jp/lifestyle/serial/01/engineer-x-manage None
# http://gihyo.jp/lifestyle None
# /lifestyle/clip/01/awt Android Weekly Topics
# /lifestyle/clip/01/awt/201804/05 2018年4月第1週　Chrome OS搭載のタブレット「Chromebook Tab 10」が発売，未認証端末でGAppsが使えない日が来る？！
# http://gihyo.jp/lifestyle/clip/01/awt None
# http://gihyo.jp/design None
# /design/clip/01/weekly-web-tech 週刊Webテク通信
# /design/clip/01/weekly-web-tech/201804/05 2018年4月第1週号 1位は，ユーザーの時間を奪わないためのウェブデザインのヒント，気になるネタは，「Alexa，子供服はどこで取り扱っている？」 池袋PARCOで「Amazon Echo」が館内案内
# http://gihyo.jp/design/clip/01/weekly-web-tech None
# http://gihyo.jp/book None
# /book/pickup 新刊ピックアップ
# /book/pickup/2018/0019 無料の動画編集ソフトAviUtlで手軽に実況動画を作ってみよう
# http://gihyo.jp/book None
# /book/pickup 新刊ピックアップ
# /book/pickup/2018/0018 クラウド時代のサーバ技術者に求められるスキルとは
# http://gihyo.jp/admin None
# /admin/clip/01/linux_dt Linux Daily Topics
# /admin/clip/01/linux_dt/201804/04 2018年4月4日　Linux 4.16がリリース ―Jailhouseハイパーバイザのサポート，usercopyホワイトリストなど
# http://gihyo.jp/admin/clip/01/linux_dt None
# http://gihyo.jp/admin None
# /admin/serial/01/ubuntu-recipe Ubuntu Weekly Recipe
# /admin/serial/01/ubuntu-recipe/0514 第514回　Intel RealSense D435でバーチャルユーチューバーの深みを味わう
# http://gihyo.jp/admin/serial/01/ubuntu-recipe None
# http://gihyo.jp/dev None
# /dev/column 一般記事
# /dev/column/01/iot/2018/iot-engeneer 【イベント開催連動企画】社会に浸透するIoT ～エンジニアが主人公になる時代がやってきた
# http://gihyo.jp/dev/column/01/iot/2018/iot-engeneer None
# http://gihyo.jp/book None
# /book/pickup 新刊ピックアップ
# /book/pickup/2018/0017 時系列分析とは？ ～気温や株価を予想するための考え方～
# contentslist 記事一覧
# news/report/2017/11/0801 「ECHO Tokyo 2017」で見えた業務アプリ開発の未来
# news/report/2017/11/0801 None
# ad/01/atlassian 開発スピードに限界を感じたときの処方箋
# http://gihyo.jp/ad/01/atlassian None
# ad/2017/ricksoft-rec ［Special Interview］3年で300%急成長のベンチャーがSE・PGを大募集！！
# http://gihyo.jp/ad/2017/ricksoft-rec None
# news/interview/01/kadokawa_it ［特別広報］IPとITが融合する新プロジェクトが始動！ エンジニアよ，KADOKAWAで世界を目指せ
# http://gihyo.jp/news/interview/01/kadokawa_it None
# http://gihyo.jp/news/interview/01/getting-started 羽生章洋『はじめよう！システム設計』刊行記念特別インタビュー～角征典から見た2018年の上流工程とカスタマーエクスペリエンスの時代
# http://gihyo.jp/news/interview/01/getting-started None
# http://gihyo.jp/admin/serial/01/infrasec インフラセキュリティの処方箋
# http://gihyo.jp/admin/serial/01/infrasec None
# http://gihyo.jp/dev/serial/01/vuejs Vue.js入門 ―最速で作るシンプルなWebアプリケーション
# http://gihyo.jp/dev/serial/01/vuejs None
# http://gihyo.jp/dev/serial/01/oss-db-various-news OSSデータベース取り取り時報
# http://gihyo.jp/dev/serial/01/oss-db-various-news None
# http://gihyo.jp/dev/serial/01/funny-play きたみりゅうじの聞かせて珍プレー
# http://gihyo.jp/dev/serial/01/funny-play None
# http://gihyo.jp/lifestyle/serial/01/engineer-x-manage エンジニアと経営のクロスオーバー
# http://gihyo.jp/lifestyle/serial/01/engineer-x-manage None
# http://gihyo.jp/admin/clip/01/linux_dt Linux Daily Topics
# http://gihyo.jp/admin/clip/01/linux_dt None
# http://gihyo.jp/design/serial/01/website-pickup いま，見ておきたいウェブサイト
# http://gihyo.jp/design/serial/01/website-pickup None
# http://gihyo.jp/serial 連載一覧
# ad/01/gloops 人気ソーシャルアプリを支えるグループスのインフラ環境／開発現場に迫る!!
# ad/01/azure_frontier Windows Azure ユーザーズフロンティア
# ad/01/mixi_infra 大規模ソーシャルサービス mixiを支える技術
# ad/01/infra gihyo.jp インフラエンジニア情報局
# ad/01/power_up エンジニアパワーアップ講座 ～システム基盤を活用するための基礎知識～
# ad/2008/test テストエンジニア ステーション
# news/interview/20090406 IVIAに賭けた日本のテスト技術への想い
# http://gihyo.jp/design/serial/01/net_dynamism 疾走するネット・ダイナミズム
# ad/01/hosting レンタルサーバ導入ガイド
# http://gihyo.jp/ None
# http://gihyo.jp/dev デベロッパ
# http://gihyo.jp/admin アドミニストレータ
# http://gihyo.jp/design WEB+デザイン
# http://gihyo.jp/lifestyle ライフスタイル
# http://gihyo.jp/science サイエンス
# http://gihyo.jp/news ニュース&レポート
# http://gihyo.jp/book 書籍案内
# http://gihyo.jp/book/list 新刊書籍
# http://gihyo.jp/book/genre 書籍ジャンル一覧
# http://gihyo.jp/book/series 書籍シリーズ一覧
# http://gihyo.jp/book/pickup 新刊ピックアップ
# http://gihyo.jp/book/longseller ロングセラー
# http://gihyo.jp/book/dennou 電脳会議
# http://gihyo.jp/magazine 定期刊行物一覧
# http://gihyo.jp/magazine/SD Software Design
# http://gihyo.jp/magazine/wdpress WEB+DB PRESS
# https://gihyo.jp/dp None
# https://gihyo.jp/dp/information お知らせ
# https://gihyo.jp/dp/help ご購入方法・読み方
# https://gihyo.jp/dev/serial/01/funny-play/form None
# http://gihyo.jp/tagList/FreeBSD FreeBSD
# http://gihyo.jp/tagList/Ubuntu Ubuntu
# http://gihyo.jp/tagList/Linux Linux
# http://gihyo.jp/tagList/Web%E3%83%87%E3%82%B6%E3%82%A4%E3%83%B3 Webデザイン
# http://gihyo.jp/tagList/%E3%82%B9%E3%83%9E%E3%83%BC%E3%83%88%E3%83%95%E3%82%A9%E3%83%B3 スマートフォン
# http://gihyo.jp/tagList/Android Android
# http://gihyo.jp/tagList/Web%E5%BA%83%E5%91%8A Web広告
# http://gihyo.jp/tagList/%E3%82%AF%E3%83%A9%E3%82%A6%E3%83%89 クラウド
# http://gihyo.jp/tagList [ タグ一覧 ]
# http://gihyo.jp/admin/serial/01/ubuntu-recipe/0514 第514回　Intel RealSense D435でバーチャルユーチューバーの深みを味わう
# http://gihyo.jp/admin/clip/01/linux_dt/201804/04 2018年4月4日　Linux 4.16がリリース ―Jailhouseハイパーバイザのサポート，usercopyホワイトリストなど
# http://gihyo.jp/lifestyle/clip/01/awt/201804/05 2018年4月第1週　Chrome OS搭載のタブレット「Chromebook Tab 10」が発売，未認証端末でGAppsが使えない日が来る？！
# http://gihyo.jp/lifestyle/serial/01/engineer-x-manage/0011 第11回　営業をやるとエンジニアライフに絶対にプラスになる
# http://gihyo.jp/admin/clip/01/linux_dt/201804/05 2018年4月5日　モジュラー化に再挑戦した「Fedora 28」ベータ版が登場，正式リリースは5月8日予定
# http://gihyo.jp/admin/clip/01/linux_dt/201804/02 2018年4月2日　最低でも20年 ―東芝らが取り組む"スーパーロングなカーネルサポート"プロジェクト
# http://gihyo.jp/book/pickup/2018/0017 時系列分析とは？ ～気温や株価を予想するための考え方～
# http://gihyo.jp/admin/serial/01/bsd-yomoyama/0142 第142回　FreeBSD Meltdown対策機能による性能影響ベンチマーク
# http://gihyo.jp/dev/column/01/iot/2018/iot-engeneer 【イベント開催連動企画】社会に浸透するIoT ～エンジニアが主人公になる時代がやってきた
# http://gihyo.jp/design/clip/01/weekly-web-tech/201804/05 2018年4月第1週号 1位は，ユーザーの時間を奪わないためのウェブデザインのヒント，気になるネタは，「Alexa，子供服はどこで取り扱っている？」 池袋PARCOで「Amazon Echo」が館内案内
# http://gihyo.jp/ad/pr/2018/NRR2018159879 世界最大級の求人検索エンジンのIndeed標準連携
# ※採用サイト制作...
# http://gihyo.jp/ad/pr/2018/NRR2018159887 伊藤嘉洋・武部力也の週間相場見通しの最新号を公開しました【岡...
# http://gihyo.jp/ad/pr/2018/NRR2018159882 武部力也のミニセミナー『株と為替の売買シナリオ』(4月6日分)公...
# http://gihyo.jp/ad/pr/2018/NRR2018159868 次世代モビリティオープンなど話題の投信１７銘柄 購入時手数料...
# http://gihyo.jp/ad/pr/2018/NRR2018159871 営業支援(SFA)ツールcyzen（サイゼン）アプリで営業現場の生産性...
# http://gihyo.jp/ad/pr [ 企業動向一覧 ]
# http://gihyo.jp/mail メールでのお知らせ
# http://gihyo.jp/mail 登録情報変更ページ
# http://gihyo.jp/site このサイトについて
# http://gihyo.jp/site/profile 会社案内
# http://gihyo.jp/site/policy プライバシーポリシー
# http://gihyo.jp/site/social ソーシャルメディアの運用について
# http://gihyo.jp/site/purchase 刊行物の購入について
# http://gihyo.jp/site/ad 広告出稿のご案内
# http://gihyo.jp/site/inquiry お問い合わせ
# http://gihyo.jp/magazine/SD None
# http://gihyo.jp/magazine/wdpress None
# http://gihyo.jp/feed RSS/ATOM
# /#header このページの先頭へ
# http://www.gihyo.co.jp/ None
